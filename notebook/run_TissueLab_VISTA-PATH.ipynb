# %% [markdown]
# # Applying VISTA-PATH in TissueLab
#
# **Author:** Peixian Liang
# **Project:** VISTA-PATH – Segmentation Foundation Model for Computational Pathology
#
# ---
#
# This tutorial demonstrates how to:
#
# 1. Load whole-slide images (WSIs)
# 2. Run VISTA-PATH segmentation
# 3. Export predictions
# 4. Upload results into TissueLab
# 5. Perform interactive refinement and biomarker extraction
#
# ---

# %% [markdown]
# <p align="center">
#   <img src="../figures/upload_file.png" width="700">
# </p>
